# %% [markdown]
# # Vector Operations

# %%
import numpy as np

# Vector addition
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])
result = arr1 + arr2
print("Vector addition result:", result)

# Vector subtraction
result = arr1 - arr2
print("Vector subtraction result:", result) 

# Scalar multiplication
scalar = 2
result = arr1 * scalar
print("Scalar multiplication result:", result)

# Dot product
dot_product = np.dot(arr1, arr2)
print("Dot product result:", dot_product)

# Vector magnitude
magnitude = np.lialg.norm(arr1)
print("Vector magnitude:", magnitude)
